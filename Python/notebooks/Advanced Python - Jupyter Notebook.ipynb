# %% [markdown]
# <a id='top_cell'></a>

# %% [markdown]
# # Advanced Python - Jupyter Notebook
# <div style="text-align: right"> [Back to Start](0 Start.ipynb) </div>

# %% [markdown]
# * nbextension
#   * Freeze
#   * code collapse
# * using HTML in cells
# * edit meta data

# %% [markdown]
# http://blog.juliusschulz.de/blog/ultimate-ipython-notebook
# https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/

# %%
# %env

# %% [markdown]
# \\( P(A \mid B) = \frac{P(B \mid A) \, P(A)}{P(B)} \\)

# %%
# %%bash
# for i in {1..5}
# do
#    echo "i is $i"
# done
# Out:
# i is 1
# i is 2
# i is 3
# i is 4
# i is 5

# %%
# !ls -l /Users/rik/Pictures/

# %%
# !pwd
# Out:
# /Users/rik/Git/IT-workshops/Python/notebooks

# %%
# !pip list

# %%
# !conda info

# %%
import os
from IPython.display import display, Image
names = [f for f in os.listdir('/Users/rik/Pictures/') if f.endswith('.png')]
for name in names[:5]:
    display(Image('/Users/rik/Pictures/' + name, width=100))

# %% [markdown]
# View > Cell Toolbar > Edit Metadata
#
# View > Cell Toolbar > Initialization Cell

# %% [markdown]
# <div style="text-align: right"><button>[⇧ Go to top ⇧](#top_cell)</button></div>
