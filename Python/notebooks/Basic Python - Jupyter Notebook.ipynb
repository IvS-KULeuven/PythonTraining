# %% [markdown]
# <a id='top_cell'></a>

# %% [markdown]
# # Basic Python - Jupyter Notebook
# <div style="text-align: right"> [Back to Start](0 Start.ipynb) </div>

# %% [markdown]
# A jupyter notebook works as a client-server application. The server is usually started on your local system in a Terminal.

# %% [markdown]
# ```
# $ jupyter-notebook [list]
# ```

# %% [markdown]
# Options:

# %% [markdown]
# * ``--log-level=<Enum>``
# * ``--notebook-dir=<Folder>``

# %% [markdown]
# The log-level above can be an integer or one of (DEBUG=0, INFO=10, WARNING=20, **ERROR=30**, CRITICAL=40). The default is 30.
#
# Check if there are already Jupyter notebooks running on your system. This can be useful to re-connect, when you have closed the tab in your browser by accident. The token is used in the browser as an identifier to re-connect.

# %% [markdown]
# ```
# $ jupyter-notebook list
# Currently running servers:
# http://localhost:8889/?token=8b7670f4e2ba13c312d1402d3c40f2e759115b51da4fae25 :: /Users/rik/Documents/Python/Jupyter Notebooks
# http://localhost:8890/?token=6d803287c1c3447e83d38a071de19e7c86e2090b66871117 :: /Users/rik/Git/Camera-EGSE/src/demos
# http://localhost:8888/?token=a419a2e88fa1863c0b8321f95ef001a5594c564f69188e5b :: /Users/rik/Git/IT-workshops
# ```

# %% [markdown]
# ## Working with the Jupyter Notebook

# %% [markdown]
# Using the command pallet to learn keyboard shortcuts: ``⇧`` + ``⌘`` + ``P``

# %% [markdown]
# <img src="attachment:Screenshot%202018-11-02%2016.13.17.png" width=600>

# %% [markdown]
# ## Command & Edit Mode

# %% [markdown]
# The ``esc`` key will bring you into **command mode** where you basically manipulate and run cells and interact with the Jupyter Notebook itself.
#
# The ``Return`` key will bring you (back) into edit mode where you edit your code or write markdown to document your notebook.

# %% [markdown]
# ## Show documentation

# %% [markdown]
# ``⇧`` + ``TAB`` shows the documentation or docstring for the object you have just typed. Pressing ``⇧`` + ``TAB`` again will toggle you through different docstring options.
#
# Alternatively, you can add a ``?`` to the end of the object name and render the cell with ``⇧`` + ``Return``.

# %%
import numpy as np

x = np.zeros((2,3))
x
# Out:
# array([[ 0.,  0.,  0.],
#        [ 0.,  0.,  0.]])

# %%
x.shape?

# %% [markdown]
# ## Manipulating cells

# %% [markdown]
# | Key code | Action |
# |   :---:  | :---   |
# | ``⇧`` + ``Down`` | Select the next cell downwards |
# | ``⇧`` + ``Up`` | Select the next cell upwards |
# | ``a``    | Add a new cells above |
# | ``b``    | Add a new cell below |
# | ``x``    | Cut the current cell or selected cells |
# | ``c``    | Copy the current cell or selected cells |
# | ``v``    | Paste the
# | ``^`` + ``⇧`` + ``Minus``   | Split the cell at the cursor position |
# | ``⇧`` + ``M``   | Merge current and next cell |

# %% [markdown]
# ## Multicursor support

# %%
constants = {
    'one'  : 1,
    'two'  : 2,
    'three': 3,
    'four' : 4,
    'five' : 5,
    'six'  : 6,
    'seven': 7,
}

# %% [markdown]
# ## Magic commands

# %% [markdown]
# Magics are specific iPython kernel commands that you can use within Jupyter Notebook. They are mostly used for configuration purposes, but also give you access to the ``bash`` terminal commands. Check out the [iPython Magics](https://ipython.readthedocs.io/en/stable/interactive/magics.html).

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.figure(1, figsize=(10,6))
plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)
plt.plot(x2, y2, '.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.show()

# %%
x = 5
x;

# %%
# %dhist
# %cd /Users/rik/Documents/Python/Jupyter\ Notebooks
# Out:
# Directory history (kept in _dh)
# 0: /Users/rik/Git/IT-workshops/Python/notebooks
# /Users/rik/Documents/Python/Jupyter Notebooks

# %%
# %dhist
# Out:
# Directory history (kept in _dh)
# 0: /Users/rik/Git/IT-workshops/Python/notebooks
# 1: /Users/rik/Documents/Python/Jupyter Notebooks

# %%
# %pwd
# Out:
# '/Users/rik/Documents/Python/Jupyter Notebooks'

# %%
# %load "~/Git/IT-workshops/Python/scripts/numpy_example.py"
"""
In this script, we first simulated an image of the sky by adding a number of
Gaussian stars. Then we look for the brightest star in the field and extract
the measured flux. We compare the measured flux as a function of aperture size.
"""
import matplotlib.pyplot as plt
import numpy as np
import logging

logging.basicConfig(level=logging.DEBUG) # Default level is WARNING

#-- input parameters ----------------------------------------------------------
np.random.seed(1000)
image_size = 1000,1200
number_of_stars = 50
bias = 100.
noise = 1.
#------------------------------------------------------------------------------

def star_image(image_coords, star_coords, sigma=1.0, peak_brightness=1.0):
    """
    Definition of the Gaussian PSF of a star. 
    """
    X,Y = image_coords
    star_x,star_y = star_coords
    starshape = peak_brightness * np.exp( -0.5*((X-star_x)**2 + (Y-star_y)**2) / sigma**2)
    logging.info(f"Added star at {star_coords} (sigma={sigma:.2f}, peak={peak_brightness:.2f})")
    return starshape


#--------------- GENERATE SIMULATED IMAGE -------------------------------------

#-- start with a bias image
image = bias*np.ones(image_size)
#-- create a coordinate grid of the image to easily compute distances etc.
X,Y = np.mgrid[0:image_size[0]:1,0:image_size[1]:1]
#-- create a set of random parameters to characterize the input stars.
#   This table consists of 'number_of_star' rows and 4 columns:
#       Column 1: X coordinate of star
#       Column 2: Y coordinate of star
#       Column 3: width of star
#       Column 4: star brightness
stars = np.random.uniform(low=np.array([0,0,5.2,5]),
                          high=np.array([image_size[0],image_size[1],5.5,100]),
                          size=(number_of_stars,4))
#-- See where the brightest star is located and what its total flux is.
brightest_star_input = np.argmax(stars[:,-1])
predicted_flux = 2*np.pi*stars[brightest_star_input,-2]**2*stars[brightest_star_input,-1]

#-- now add all the input stars to the image
for star in stars:
    image += star_image((X,Y),star[:2],sigma=star[2],peak_brightness=star[3])

#-- and add some random noise the image
image += np.random.normal(size=image.shape,scale=noise)
#------------------------------------------------------------------------------

#--------------- EXTRACT BRIGHTEST STAR FROM SIMULATED IMAGE ------------------

#-- first determine the bias
bias_meas = np.median(np.ravel(image))

#-- get the location of the brightest star
Xc,Yc = np.unravel_index(image.argmax(),image.shape)
logging.info (f"Location of brightest star: {Xc}, {Yc}")

#-- determine the distance from each pixel to the brightest star: we want to 
#   sum up all flux inside a region around the brightest stars (an aperture).
#   We will use different aperture sizes to see how the measured flux is
#   dependent on it
distance = np.sqrt( (X-Xc)**2 + (Y-Yc)**2)
apertures = np.linspace(0.5,5,10)*stars[:,-2].mean()

#-- prepare an array to collect the measured fluxes as a function of aperture
measured_fluxes = np.zeros_like(apertures)

#-- now sum up the flux inside each aperture. Therefore, copy the original
#   image into a new array, and set all the flux outside the aperture to zero.
#   Then, subtract the bias and sum the whole
for i,aperture in enumerate(apertures):
    brightest_star = distance<=aperture
    extracted = image+0.
    extracted[~brightest_star] = 0
    extracted[brightest_star] -= bias_meas
    measured_fluxes[i] = extracted.sum()
    logging.info(f"Aperture {aperture}: flux = {measured_fluxes[i]} (real = {predicted_flux}")

#------------------------------------------------------------------------------
#-- make a plot of the measured/predicted fluxes
plt.figure()
plt.plot(apertures,measured_fluxes,'ko-')
plt.plot(apertures,np.ones_like(apertures)*predicted_flux,'r-')

#-- make a plot of the image itself and the extracted region
plt.figure()
plt.imshow(image,cmap=plt.cm.hot)
plt.plot(Yc,Xc,'gx',ms=20,mew=2)
plt.colorbar()
plt.xlim(0,image_size[1])
plt.ylim(0,image_size[0])

plt.figure()
#-- don't plot the flux outside the extracted region
extracted[~brightest_star] = np.nan
plt.imshow(extracted,cmap=plt.cm.hot)
plt.colorbar()
plt.xlim(0,image_size[1])
plt.ylim(0,image_size[0])
plt.show();
# Out:
# INFO:root:Added star at [ 653.58958546  138.00833175] (sigma=5.49, peak=50.81)
# INFO:root:Added star at [ 872.47453518  254.79921711] (sigma=5.21, peak=42.73)
# INFO:root:Added star at [  233.13219735  1010.0888691 ] (sigma=5.26, peak=75.53)
# INFO:root:Added star at [ 392.15412781  218.70782394] (sigma=5.42, peak=11.61)
# INFO:root:Added star at [  885.33720438  1143.17327907] (sigma=5.48, peak=44.47)
# INFO:root:Added star at [   28.98165939  1178.43298152] (sigma=5.30, peak=72.14)
# INFO:root:Added star at [ 361.87706761   42.12707754] (sigma=5.46, peak=67.44)
# INFO:root:Added star at [ 765.68299415  664.90468561] (sigma=5.47, peak=90.90)
# INFO:root:Added star at [ 10.42170056  89.46808337] (sigma=5.27, peak=17.66)
# INFO:root:Added star at [ 697.92510041  477.84586023] (sigma=5.46, peak=22.20)
# INFO:root:Added star at [ 432.49917179   21.77184331] (sigma=5.41, peak=49.62)
# INFO:root:Added star at [  128.22218965  1069.60446155] (sigma=5.48, peak=11.95)
# INFO:root:Added star at [  45.44794323  526.28747489] (sigma=5.38, peak=34.47)
# INFO:root:Added star at [ 681.90824199  250.81578101] (sigma=5.36, peak=58.77)
# INFO:root:Added star at [ 441.16739259  165.06738865] (sigma=5.26, peak=17.67)
# INFO:root:Added star at [ 322.2967015   280.66453821] (sigma=5.36, peak=58.77)
# INFO:root:Added star at [ 438.22528479  386.2471489 ] (sigma=5.37, peak=87.21)
# INFO:root:Added star at [ 847.28287738  129.38059918] (sigma=5.29, peak=43.90)
# INFO:root:Added star at [ 687.08901392  842.68234497] (sigma=5.33, peak=44.93)
# INFO:root:Added star at [ 802.63059107  646.34107838] (sigma=5.48, peak=10.88)
# INFO:root:Added star at [  367.58345334  1164.47852694] (sigma=5.41, peak=89.64)
# INFO:root:Added star at [ 253.55271839  870.63252699] (sigma=5.26, peak=56.06)
# INFO:root:Added star at [ 236.94300373  523.79059172] (sigma=5.44, peak=34.30)
# INFO:root:Added star at [ 621.5166285   527.57774117] (sigma=5.47, peak=67.58)
# INFO:root:Added star at [ 653.63144812  430.14934006] (sigma=5.36, peak=9.28)
# INFO:root:Added star at [   94.3096619   1105.93463167] (sigma=5.22, peak=93.29)
# INFO:root:Added star at [ 717.01513712  746.77265489] (sigma=5.43, peak=18.46)
# INFO:root:Added star at [ 793.8221977   870.48377987] (sigma=5.36, peak=50.85)
# INFO:root:Added star at [ 476.47761037  535.23939653] (sigma=5.44, peak=31.06)
# INFO:root:Added star at [   61.96200768  1152.35561   ] (sigma=5.34, peak=77.00)
# INFO:root:Added star at [ 681.1586028   650.13351093] (sigma=5.24, peak=29.05)
# INFO:root:Added star at [ 443.85559307  670.499888  ] (sigma=5.44, peak=35.19)
# INFO:root:Added star at [  397.04509317  1068.20189795] (sigma=5.45, peak=15.14)
# INFO:root:Added star at [ 159.77587557  781.46317037] (sigma=5.37, peak=98.49)
# INFO:root:Added star at [ 749.15901266  962.87955703] (sigma=5.27, peak=54.28)
# INFO:root:Added star at [ 630.10840311    2.62243373] (sigma=5.35, peak=47.67)
# INFO:root:Added star at [ 349.35635039  328.41751125] (sigma=5.47, peak=7.94)
# INFO:root:Added star at [ 324.16908982  343.91129718] (sigma=5.49, peak=6.57)
# INFO:root:Added star at [ 457.32367323  389.92295517] (sigma=5.41, peak=70.81)
# INFO:root:Added star at [  682.64606925  1070.55654962] (sigma=5.48, peak=12.77)
# INFO:root:Added star at [ 116.88922055   44.24276067] (sigma=5.48, peak=98.28)
# INFO:root:Added star at [ 376.62525332   76.17120874] (sigma=5.24, peak=88.59)
# INFO:root:Added star at [ 454.04813484  239.38927463] (sigma=5.39, peak=78.76)
# INFO:root:Added star at [ 464.54819403   48.44018138] (sigma=5.31, peak=87.36)
# INFO:root:Added star at [ 103.20552705  135.01334366] (sigma=5.43, peak=17.83)
# INFO:root:Added star at [ 128.55847211  288.60380989] (sigma=5.29, peak=36.66)
# INFO:root:Added star at [ 792.16401614  293.21631322] (sigma=5.23, peak=16.12)
# INFO:root:Added star at [ 359.35112539  280.72839405] (sigma=5.45, peak=63.02)
# INFO:root:Added star at [  289.99069448  1196.92618664] (sigma=5.33, peak=90.00)
# INFO:root:Added star at [ 288.24616441  376.13390667] (sigma=5.49, peak=13.47)
# INFO:root:Location of brightest star: 117, 44
# INFO:root:Aperture 2.688857958815081: flux = 1953.737291243332 (real = 17849.574384395455
# INFO:root:Aperture 5.377715917630162: flux = 6979.0734564227205 (real = 17849.574384395455
# INFO:root:Aperture 8.066573876445243: flux = 12543.790022662068 (real = 17849.574384395455
# INFO:root:Aperture 10.755431835260325: flux = 15734.79566717674 (real = 17849.574384395455
# INFO:root:Aperture 13.444289794075406: flux = 17605.260185685813 (real = 17849.574384395455
# INFO:root:Aperture 16.133147752890487: flux = 18269.929331883202 (real = 17849.574384395455
# INFO:root:Aperture 18.822005711705568: flux = 18445.3145582244 (real = 17849.574384395455
# INFO:root:Aperture 21.51086367052065: flux = 18490.24393302009 (real = 17849.574384395455
# INFO:root:Aperture 24.19972162933573: flux = 18444.659403406105 (real = 17849.574384395455
# INFO:root:Aperture 26.88857958815081: flux = 18464.300869585823 (real = 17849.574384395455

# %%
# %cd ~/Git/IT-workshops/Python/scripts
# Out:
# /Users/rik/Git/IT-workshops/Python/scripts

# %%
# %load numpy_example.py

# %%
# %run swap.py
# Out:
# x=5
# y=10
# x=10
# y=5

# %%
# %load swap.py
# Swap two variables

x = 5
y = 10

print (f"x={x}")
print (f"y={y}")

(x, y) = (y, x)

print (f"x={x}")
print (f"y={y}")

# %% [markdown]
# <div style="text-align: right"> [Next: Logging](Basic Python - Logging.ipynb) </div>

# %% [markdown]
# <div style="text-align: right"><button>[⇧ Go to top ⇧](#top_cell)</button></div>
